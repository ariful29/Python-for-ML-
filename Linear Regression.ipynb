# %%
import matplotlib.pyplot as plt



list1= [22,45,75,54,67,78]
print(list1)
print(len(list1))
list1.append(11)
print(list1)
print(len(list1))


#Dataset
x=[0,1,2,3]
y=[4,7,7,8]

#parameter initialization
theta=[2,2]


                                    #print(theta[0])
                                    #print(theta[1])

n=0
J=10000
for i in range(10):
  print("Iteration no is:",n+1)                               
  #hypothesis function
  h = []
  for i in range(len(x)):
    temp=theta[0]+theta[1]*x[i]
    h.append(temp)

  print("Hypothesis function is:",h)
    
  #cost function
  errorsum=0
  m=len(x)
  for i in range(m):
    errorsum=errorsum+(h[i]-y[i])**2
  J=(1/(2*m))*errorsum
  print("Cost function value is:",J)

  #Gradient Decent
  temp0=0

  m=len(x)
  alpha=0.01

  for i in range(m):
    temp0=temp0+(h[i]-y[i])
  theta[0]=theta[0]-(alpha/m)*temp0
  temp1=0
  for i in range(m):
    temp1=temp1+(h[i]-y[i])*x[i]
  theta[1]=theta[1]-(alpha/m)*temp1

  print("Theta is:",theta)
  n=n+1

  plt.plot(x,h, marker="o")
  plt.show()

  print("Final hypothesis function value is:",h)
# Out:
# [22, 45, 75, 54, 67, 78]
# 6
# [22, 45, 75, 54, 67, 78, 11]
# 7
# Iteration no is: 1
# Hypothesis function is: [2, 4, 6, 8]
# Cost function value is: 1.75
# Theta is: [2.015, 2.0125]
# Final hypothesis function value is: [2, 4, 6, 8]
# Iteration no is: 2
# Hypothesis function is: [2.015, 4.0275, 6.040000000000001, 8.0525]
# Cost function value is: 1.7125421875
# Theta is: [2.0296625, 2.0243375]
# Final hypothesis function value is: [2.015, 4.0275, 6.040000000000001, 8.0525]
# Iteration no is: 3
# Hypothesis function is: [2.0296625, 4.054, 6.0783375, 8.102675000000001]
# Cost function value is: 1.6776437229296872
# Theta is: [2.0440008125, 2.03554075]
# Final hypothesis function value is: [2.0296625, 4.054, 6.0783375, 8.102675000000001]
# Iteration no is: 4
# Hypothesis function is: [2.0440008125, 4.0795415625, 6.1150823125, 8.1506230625]
# Cost function value is: 1.6450971159091032
# Theta is: [2.058027693125, 2.0461368115625]
# ...

# %% [markdown]
# 1) dataset:
# X   Y
#
# 0   4
# 1   7
# 2   7
# 3   8

# %%
#Multi variable

import matplotlib.pyplot as plt

#Dataset
x1=[1,1,2,3]
x2=[0.5,1.5,1,1]
y=[2,3,4,4]

#parameter initialization
theta=[1,0.5,1]
                                    #print(theta[0])
                                    #print(theta[1])

n=0
J=10000
for i in range(100):
  print("Iteration no is:",n+1)                               
  #hypothesis function
  h = []
  for i in range(len(x)):
    temp=theta[0]+theta[1]*x1[i]+theta[2]*x2[i]
    h.append(temp)

  print("Hypothesis function is:",h)
    
  #cost function
  errorsum=0
  m=len(x)
  for i in range(m):
    errorsum=errorsum+(h[i]-y[i])**2
  J=(1/(2*m))*errorsum
  print("Cost function value is:",J)

  #Gradient Decent
  temp0=0

  m=len(x)
  alpha=0.01

  for i in range(m):
    temp0=temp0+(h[i]-y[i])
  theta[0]=theta[0]-(alpha/m)*temp0
  temp1=0
  for i in range(m):
    temp1=temp1+(h[i]-y[i])*x1[i]
  theta[1]=theta[1]-(alpha/m)*temp1

  temp2=0
  for i in range(m):
    temp2=temp2+(h[i]-y[i])*x2[i]
  theta[2]=theta[2]-(alpha/m)*temp2
  print("Theta is:",theta)
  n=n+1

  plt.plot(x,h, marker="o")
  plt.show

  print("Final hypothesis function value is:",h)
# Out:
# Iteration no is: 1
# Hypothesis function is: [2.0, 3.0, 3.0, 3.5]
# Cost function value is: 0.15625
# Theta is: [1.00375, 0.50875, 1.00375]
# Final hypothesis function value is: [2.0, 3.0, 3.0, 3.5]
# Iteration no is: 2
# Hypothesis function is: [2.014375, 3.0181249999999995, 3.0250000000000004, 3.5337500000000004]
# Cost function value is: 0.14606865234374986
# Theta is: [1.0072718749999998, 0.517040625, 1.0072671874999999]
# Final hypothesis function value is: [2.014375, 3.0181249999999995, 3.0250000000000004, 3.5337500000000004]
# Iteration no is: 3
# Hypothesis function is: [2.02794609375, 3.0352132812499995, 3.0486203124999998, 3.5656609374999997]
# Cost function value is: 0.1369743362916566
# Theta is: [1.0105782734374997, 0.5248971679687501, 1.0105645019531249]
# Final hypothesis function value is: [2.02794609375, 3.0352132812499995, 3.0486203124999998, 3.5656609374999997]
# Iteration no is: 4
# ...
